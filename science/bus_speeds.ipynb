# %%
import polars as pl
from dotenv import dotenv_values
import geopandas as gpd
import requests
from io import StringIO

config = dotenv_values(".env")

# %%
cfg = pl.Config()
cfg.set_tbl_rows(50)
cfg.set_fmt_str_lengths(100)
# Out:
# polars.config.Config

# %%
# r = requests.get("https://trainstat.us/api/v1/stops?route_type=bus").text
# pl.read_json(StringIO(r))

# %%
df = pl.read_csv(
    "data/MTA_Bus_Route_Segment_Speeds__Beginning_2023_20250127.csv",
)

# %%
df = df.with_columns(
    Timestamp=pl.col("Timestamp").str.to_datetime("%m/%d/%Y %I:%M:%S %p")
)

# %%
df.sort("Timestamp", descending=True)
# Out:
# shape: (11_656_097, 24)
# ┌──────┬───────┬──────────────┬────────┬───┬──────────────┬──────────┬──────────────┬──────────────┐
# │ Year ┆ Month ┆ Timestamp    ┆ Day of ┆ … ┆ Average Road ┆ Bus Trip ┆ Timepoint    ┆ Next         │
# │ ---  ┆ ---   ┆ ---          ┆ Week   ┆   ┆ Speed        ┆ Count    ┆ Stop         ┆ Timepoint    │
# │ i64  ┆ i64   ┆ datetime[μs] ┆ ---    ┆   ┆ ---          ┆ ---      ┆ Georeference ┆ Stop         │
# │      ┆       ┆              ┆ str    ┆   ┆ f64          ┆ i64      ┆ ---          ┆ Georeference │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ str          ┆ ---          │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆              ┆ str          │
# ╞══════╪═══════╪══════════════╪════════╪═══╪══════════════╪══════════╪══════════════╪══════════════╡
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 4.384888     ┆ 2        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.977104  ┆ (-73.9688    │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.758431)   ┆ 40.754881)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 10.300956    ┆ 7        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.815117  ┆ (-73.813593  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.765633)   ┆ 40.785497)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 12.148265    ┆ 10       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.821999  ┆ (-73.826535  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.826154)   ┆ 40.813235)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 7.153986     ┆ 9        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.954489  ┆ (-73.94997   │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.820642)   ┆ 40.826791)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 16.827909    ┆ 6        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-74.145849  ┆ (-74.166551  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.589154)   ┆ 40.578047)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 10.60876     ┆ 3        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.871784  ┆ (-73.84404   │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.675497)   ┆ 40.680362)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 8.538582     ┆ 20       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.883617  ┆ (-73.877775  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.666382)   ┆ 40.658352)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 10.223852    ┆ 8        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.920997  ┆ (-73.906891  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.867705)   ┆ 40.877199)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 9.10212      ┆ 8        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.814763  ┆ (-73.829892  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.732447)   ┆ 40.759377)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 8.723171     ┆ 8        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.941954  ┆ (-73.921794  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.600372)   ┆ 40.610106)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 11.981823    ┆ 4        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.954283  ┆ (-73.95525   │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.819614)   ┆ 40.814859)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 10.823199    ┆ 4        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.972382  ┆ (-73.97997   │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.756659)   ┆ 40.746315)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 9.44524      ┆ 8        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.871784  ┆ (-73.866629  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.675497)   ┆ 40.653144)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 10.894737    ┆ 3        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.815117  ┆ (-73.813593  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.765633)   ┆ 40.785497)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 2.44827      ┆ 12       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.843949  ┆ (-73.844686  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.721784)   ┆ 40.722097)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 6.390875     ┆ 6        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.954489  ┆ (-73.944519  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.820642)   ┆ 40.834257)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 7.046807     ┆ 8        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.911769  ┆ (-73.919467  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.70005)    ┆ 40.704385)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 6.502003     ┆ 7        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.990292  ┆ (-73.9855    │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.731354)   ┆ 40.744106)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 7.970245     ┆ 11       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.899631  ┆ (-73.895237  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.676821)   ┆ 40.66909)    │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 9.422645     ┆ 7        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.944587  ┆ (-73.936042  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.800274)   ┆ 40.821204)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 5.745505     ┆ 18       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.945491  ┆ (-73.951246  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.784528)   ┆ 40.786099)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 8.839437     ┆ 6        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.876107  ┆ (-73.875288  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.770078)   ┆ 40.762602)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 6.793552     ┆ 6        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.909993  ┆ (-73.922704  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.700421)   ┆ 40.689479)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 13.198373    ┆ 8        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.784759  ┆ (-73.820088  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.595194)   ┆ 40.601521)   │
# │ 2024 ┆ 12    ┆ 2024-12-01   ┆ Friday ┆ … ┆ 7.362196     ┆ 11       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 23:00:00     ┆        ┆   ┆              ┆          ┆ (-73.895692  ┆ (-73.900009  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.828462)   ┆ 40.831137)   │
# │ …    ┆ …     ┆ …            ┆ …      ┆ … ┆ …            ┆ …        ┆ …            ┆ …            │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 8.666946     ┆ 13       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.919561  ┆ (-73.93689   │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.847651)   ┆ 40.849011)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 9.173717     ┆ 15       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.919561  ┆ (-73.93775   │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.847651)   ┆ 40.849112)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 7.524168     ┆ 10       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.961729  ┆ (-73.947916  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.698573)   ┆ 40.703994)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 7.284466     ┆ 10       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.791742  ┆ (-73.792909  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.704734)   ┆ 40.710811)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 12.621794    ┆ 10       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.935122  ┆ (-73.93101   │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.796323)   ┆ 40.797614)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 10.861898    ┆ 8        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.741346  ┆ (-73.730337  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.701788)   ┆ 40.702108)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 8.386535     ┆ 10       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.937807  ┆ (-73.960435  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.622955)   ┆ 40.618027)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 14.707407    ┆ 5        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.867265  ┆ (-73.872839  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.703406)   ┆ 40.725163)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 8.90021      ┆ 10       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.845946  ┆ (-73.856248  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.773561)   ┆ 40.785723)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 9.891458     ┆ 5        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.895756  ┆ (-73.904027  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.732116)   ┆ 40.745114)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 18.589639    ┆ 8        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.873953  ┆ (-73.889176  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.689205)   ┆ 40.698624)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 9.061792     ┆ 9        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.991161  ┆ (-73.992014  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.696635)   ┆ 40.702547)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 9.606703     ┆ 13       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.982815  ┆ (-73.987134  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.689671)   ┆ 40.691398)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 12.493329    ┆ 10       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.878354  ┆ (-73.902111  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.643015)   ┆ 40.645679)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 10.354669    ┆ 10       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.999159  ┆ (-73.991279  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.733369)   ┆ 40.730069)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 11.466281    ┆ 10       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.7537    ┆ (-73.735745  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.724847)   ┆ 40.718247)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 11.07429     ┆ 8        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.943357  ┆ (-73.926402  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.607307)   ┆ 40.612861)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 9.279026     ┆ 15       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.943357  ┆ (-73.934953  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.607307)   ┆ 40.601568)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 8.209175     ┆ 9        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.982815  ┆ (-73.990409  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.689671)   ┆ 40.693869)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 9.418885     ┆ 9        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.982815  ┆ (-73.991161  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.689671)   ┆ 40.696635)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 9.58019      ┆ 10       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.829892  ┆ (-73.837008  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.759377)   ┆ 40.772893)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 7.784542     ┆ 10       ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.829892  ┆ (-73.845946  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.759377)   ┆ 40.773561)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 8.037924     ┆ 8        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.983129  ┆ (-73.990259  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.738982)   ┆ 40.729113)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 6.831689     ┆ 3        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.906546  ┆ (-73.920651  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.849184)   ┆ 40.831124)   │
# │ 2023 ┆ 1     ┆ 2023-01-01   ┆ Sunday ┆ … ┆ 15.160542    ┆ 2        ┆ POINT        ┆ POINT        │
# │      ┆       ┆ 00:00:00     ┆        ┆   ┆              ┆          ┆ (-73.873953  ┆ (-73.889176  │
# │      ┆       ┆              ┆        ┆   ┆              ┆          ┆ 40.689205)   ┆ 40.698624)   │
# └──────┴───────┴──────────────┴────────┴───┴──────────────┴──────────┴──────────────┴──────────────┘

# %%
gdf = gpd.read_file(r"data/stops.geojson")
gdf = gdf.set_crs(4326)
bounds = gpd.read_file(r"data/congestion_zone.geojson")
bounds = bounds.set_crs(4326)

# %%
gdf = gdf.sjoin(bounds, how="inner").drop(columns=["index_right"])
stop_ids = gdf["id"].tolist()

# %%
stop_ids_sql = f"ARRAY[{','.join(f'{id}' for id in stop_ids)}]"

query = f"""
SELECT
	t.id,
	t.vehicle_id,
	t.route_id,
	t.direction,
	t.created_at,
	t.updated_at,
	st.arrival,
	st.stop_id
FROM
	trip t
LEFT JOIN stop_time st ON
	t.id = st.trip_id
WHERE
	t.express IS NULL
	AND t.created_at::time BETWEEN '11:00' AND '16:00'
    AND t.route_id LIKE 'M%'
"""
# 7am to 10am (converted to utc)

df: pl.DataFrame = pl.read_database_uri(query, config["DATABASE_URI"])

# %%
df = df.sort(["id", "arrival"])

# %%
# df = df.with_columns(
#     travel_time=pl.col("arrival").diff().over("id"),
# ).filter(pl.col("travel_time").is_not_null())

# %%
dfg = (
    df.group_by("id", "route_id", "direction", "created_at")
    .agg(pl.col("arrival").last() - pl.col("arrival").first())
    .rename({"arrival": "travel_time"})
)
dfg = dfg.with_columns(
    travel_time=pl.col("travel_time").dt.total_minutes(),
)

# %%
dfg["route_id"].value_counts(sort=True).head(10)
# Out:
# shape: (10, 2)
# ┌──────────┬───────┐
# │ route_id ┆ count │
# │ ---      ┆ ---   │
# │ str      ┆ u32   │
# ╞══════════╪═══════╡
# │ M101     ┆ 1894  │
# │ M60+     ┆ 1731  │
# │ M15      ┆ 1707  │
# │ M86+     ┆ 1287  │
# │ M14D+    ┆ 1158  │
# │ M15+     ┆ 1028  │
# │ M102     ┆ 1016  │
# │ M125     ┆ 884   │
# │ M96      ┆ 845   │
# │ M14A+    ┆ 816   │
# └──────────┴───────┘

# %%
chart = (
    dfg.filter(pl.col("route_id") == "M14A+")
    .plot.line(x="created_at", y="travel_time")
    .properties(title="Travel time", width=800)
)
chart + chart.transform_regression("created_at", "travel_time").mark_line()
# Out:
# alt.LayerChart(...)

# %%
df_filtered = df.filter(
    (pl.col("route_id") == "M15") & (pl.col("stop_id") == 401782)
).with_columns(
    travel_time=pl.col("travel_time").dt.total_minutes(),
)

# %%
chart = df_filtered.plot.line(x="arrival", y="travel_time").properties(
    title="Travel time", width=800
)
chart
# Out:
# alt.Chart(...)

# %%
# get the average time between stops

# df = df.groupby(["stop_id", "stop_id_1"]).agg(pl.col("travel_time").mean().alias("avg_travel_time"))
df
# Out:
# shape: (117_145, 10)
# ┌────────────┬────────────┬───────────┬──────────┬───┬───────────┬───────────┬─────────┬───────────┐
# │ id         ┆ mta_id     ┆ vehicle_i ┆ route_id ┆ … ┆ updated_a ┆ arrival   ┆ stop_id ┆ travel_ti │
# │ ---        ┆ ---        ┆ d         ┆ ---      ┆   ┆ t         ┆ ---       ┆ ---     ┆ me        │
# │ str        ┆ str        ┆ ---       ┆ str      ┆   ┆ ---       ┆ datetime[ ┆ i32     ┆ ---       │
# │            ┆            ┆ str       ┆          ┆   ┆ datetime[ ┆ μs, UTC]  ┆         ┆ duration[ │
# │            ┆            ┆           ┆          ┆   ┆ μs, UTC]  ┆           ┆         ┆ μs]       │
# ╞════════════╪════════════╪═══════════╪══════════╪═══╪═══════════╪═══════════╪═════════╪═══════════╡
# │ 0193e298-6 ┆ OH_D4-Week ┆ 5978      ┆ M15      ┆ … ┆ 2024-12-2 ┆ 2024-12-2 ┆ 401779  ┆ null      │
# │ c0c-70c2-b ┆ day-SDon-0 ┆           ┆          ┆   ┆ 0 07:52:1 ┆ 0         ┆         ┆           │
# │ 7f3-5b7577 ┆ 12000_M15_ ┆           ┆          ┆   ┆ 0.319158  ┆ 07:33:37  ┆         ┆           │
# │ …          ┆ …          ┆           ┆          ┆   ┆ UTC       ┆ UTC       ┆         ┆           │
# │ 0193e298-6 ┆ OH_D4-Week ┆ 5978      ┆ M15      ┆ … ┆ 2024-12-2 ┆ 2024-12-2 ┆ 401780  ┆ 39s       │
# │ c0c-70c2-b ┆ day-SDon-0 ┆           ┆          ┆   ┆ 0 07:52:1 ┆ 0         ┆         ┆           │
# │ 7f3-5b7577 ┆ 12000_M15_ ┆           ┆          ┆   ┆ 0.319158  ┆ 07:34:16  ┆         ┆           │
# │ …          ┆ …          ┆           ┆          ┆   ┆ UTC       ┆ UTC       ┆         ┆           │
# │ 0193e298-6 ┆ OH_D4-Week ┆ 5978      ┆ M15      ┆ … ┆ 2024-12-2 ┆ 2024-12-2 ┆ 401781  ┆ 27s       │
# │ c0c-70c2-b ┆ day-SDon-0 ┆           ┆          ┆   ┆ 0 07:52:1 ┆ 0         ┆         ┆           │
# │ 7f3-5b7577 ┆ 12000_M15_ ┆           ┆          ┆   ┆ 0.319158  ┆ 07:34:43  ┆         ┆           │
# │ …          ┆ …          ┆           ┆          ┆   ┆ UTC       ┆ UTC       ┆         ┆           │
# │ 0193e298-6 ┆ OH_D4-Week ┆ 5978      ┆ M15      ┆ … ┆ 2024-12-2 ┆ 2024-12-2 ┆ 401782  ┆ 12s       │
# │ c0c-70c2-b ┆ day-SDon-0 ┆           ┆          ┆   ┆ 0 07:52:1 ┆ 0         ┆         ┆           │
# │ 7f3-5b7577 ┆ 12000_M15_ ┆           ┆          ┆   ┆ 0.319158  ┆ 07:34:55  ┆         ┆           │
# │ …          ┆ …          ┆           ┆          ┆   ┆ UTC       ┆ UTC       ┆         ┆           │
# │ 0193e298-6 ┆ OH_D4-Week ┆ 5978      ┆ M15      ┆ … ┆ 2024-12-2 ┆ 2024-12-2 ┆ 404105  ┆ 57s       │
# │ c0c-70c2-b ┆ day-SDon-0 ┆           ┆          ┆   ┆ 0 07:52:1 ┆ 0         ┆         ┆           │
# │ 7f3-5b7577 ┆ 12000_M15_ ┆           ┆          ┆   ┆ 0.319158  ┆ 07:35:52  ┆         ┆           │
# │ …          ┆ …          ┆           ┆          ┆   ┆ UTC       ┆ UTC       ┆         ┆           │
# │ 0193e298-6 ┆ OH_D4-Week ┆ 5978      ┆ M15      ┆ … ┆ 2024-12-2 ┆ 2024-12-2 ┆ 401784  ┆ 20s       │
# │ c0c-70c2-b ┆ day-SDon-0 ┆           ┆          ┆   ┆ 0 07:52:1 ┆ 0         ┆         ┆           │
# │ 7f3-5b7577 ┆ 12000_M15_ ┆           ┆          ┆   ┆ 0.319158  ┆ 07:36:12  ┆         ┆           │
# │ …          ┆ …          ┆           ┆          ┆   ┆ UTC       ┆ UTC       ┆         ┆           │
# │ 0193e298-6 ┆ OH_D4-Week ┆ 5978      ┆ M15      ┆ … ┆ 2024-12-2 ┆ 2024-12-2 ┆ 
a ┆ day-SDon-0 ┆           ┆          ┆   ┆ 9 11:53:2 ┆ 9         ┆         ┆           │
# │ 099-81edc1 ┆ 38000_SBS1 ┆           ┆          ┆   ┆ 0.851107  ┆ 11:26:47  ┆         ┆           │
# │ …          ┆ …          ┆           ┆          ┆   ┆ UTC       ┆ UTC       ┆         ┆           │
# │ 01944acb-b ┆ MQ_A5-Week ┆ 6152      ┆ M14A+    ┆ … ┆ 2025-01-0 ┆ 2025-01-0 ┆ 403556  ┆ 1m 31s    │
# │ a9e-7273-a ┆ day-SDon-0 ┆           ┆          ┆   ┆ 9 11:53:2 ┆ 9         ┆         ┆           │
# │ 099-81edc1 ┆ 38000_SBS1 ┆           ┆          ┆   ┆ 0.851107  ┆ 11:28:18  ┆         ┆           │
# │ …          ┆ …          ┆           ┆          ┆   ┆ UTC       ┆ UTC       ┆         ┆           │
# │ 01944acb-b ┆ MQ_A5-Week ┆ 6152      ┆ M14A+    ┆ … ┆ 2025-01-0 ┆ 2025-01-0 ┆ 401191  ┆ 1m 3s     │
# │ a9e-7273-a ┆ day-SDon-0 ┆           ┆          ┆   ┆ 9 11:53:2 ┆ 9         ┆         ┆           │
# │ 099-81edc1 ┆ 38000_SBS1 ┆           ┆          ┆   ┆ 0.851107  ┆ 11:29:21  ┆         ┆           │
# │ …          ┆ …          ┆           ┆          ┆   ┆ UTC       ┆ UTC       ┆         ┆           │
# │ 01944ace-8 ┆ MQ_A5-Week ┆ 7507      ┆ M9       ┆ … ┆ 2025-01-0 ┆ 2025-01-0 ┆ 403397  ┆ null      │
# │ 422-7183-8 ┆ day-SDon-0 ┆           ┆          ┆   ┆ 9 11:25:4 ┆ 9         ┆         ┆           │
# │ 3c4-36f2d8 ┆ 36000_M9_5 ┆           ┆          ┆   ┆ 5.387178  ┆ 11:26:28  ┆         ┆           │
# │ …          ┆ …          ┆           ┆          ┆   ┆ UTC       ┆ UTC       ┆         ┆           │
# │ 01944ace-8 ┆ MQ_A5-Week ┆ 7507      ┆ M9       ┆ … ┆ 2025-01-0 ┆ 2025-01-0 ┆ 803108  ┆ 1m 38s    │
# │ 422-7183-8 ┆ day-SDon-0 ┆           ┆          ┆   ┆ 9 11:25:4 ┆ 9         ┆         ┆           │
# │ 3c4-36f2d8 ┆ 36000_M9_5 ┆           ┆          ┆   ┆ 5.387178  ┆ 11:28:06  ┆         ┆           │
# │ …          ┆ …          ┆           ┆          ┆   ┆ UTC       ┆ UTC       ┆         ┆           │
# │ 01944ace-8 ┆ MQ_A5-Week ┆ 5505      ┆ M23+     ┆ … ┆ 2025-01-0 ┆ 2025-01-0 ┆ 404085  ┆ null      │
# │ 4af-7ee1-9 ┆ day-SDon-0 ┆           ┆          ┆   ┆ 9 11:26:2 ┆ 9         ┆         ┆           │
# │ f0d-a7e813 ┆ 36000_SBS2 ┆           ┆          ┆   ┆ 2.036765  ┆ 11:26:06  ┆         ┆           │
# │ …          ┆ …          ┆           ┆          ┆   ┆ UTC       ┆ UTC       ┆         ┆           │
# │ 01944acf-a ┆ MQ_A5-Week ┆ 4969      ┆ M42      ┆ … ┆ 2025-01-0 ┆ 2025-01-0 ┆ 401851  ┆ null      │
# │ 0fa-7fc3-8 ┆ day-SDon-0 ┆           ┆          ┆   ┆ 9 11:34:1 ┆ 9         ┆         ┆           │
# │ 213-55cf17 ┆ 38000_M42_ ┆           ┆          ┆   ┆ 8.154905  ┆ 11:26:44  ┆         ┆           │
# │ …          ┆ …          ┆           ┆          ┆   ┆ UTC       ┆ UTC       ┆         ┆           │
# │ 01944acf-a ┆ MQ_A5-Week ┆ 4969      ┆ M42      ┆ … ┆ 2025-01-0 ┆ 2025-01-0 ┆ 401852  ┆ 1m 7s     │
# │ 0fa-7fc3-8 ┆ day-SDon-0 ┆           ┆          ┆   ┆ 9 11:34:1 ┆ 9         ┆         ┆           │
# │ 213-55cf17 ┆ 38000_M42_ ┆           ┆          ┆   ┆ 8.154905  ┆ 11:27:51  ┆         ┆           │
# │ …          ┆ …          ┆           ┆          ┆   ┆ UTC       ┆ UTC       ┆         ┆           │
# │ 01944acf-a ┆ MQ_A5-Week ┆ 4969      ┆ M42      ┆ … ┆ 2025-01-0 ┆ 2025-01-0 ┆ 401853  ┆ 2m 5s     │
# │ 0fa-7fc3-8 ┆ day-SDon-0 ┆           ┆          ┆   ┆ 9 11:34:1 ┆ 9         ┆         ┆           │
# │ 213-55cf17 ┆ 38000_M42_ ┆           ┆          ┆   ┆ 8.154905  ┆ 11:29:56  ┆         ┆           │
# │ …          ┆ …          ┆           ┆          ┆   ┆ UTC       ┆ UTC       ┆         ┆           │
# │ 01944ad1-4 ┆ MQ_A5-Week ┆ 5514      ┆ M23+     ┆ … ┆ 2025-01-0 ┆ 2025-01-0 ┆ 402134  ┆ null      │
# │ e44-7921-b ┆ day-SDon-0 ┆           ┆          ┆   ┆ 9 11:33:4 ┆ 9         ┆         ┆           │
# │ fde-5772f8 ┆ 36100_SBS2 ┆           ┆          ┆   ┆ 1.806169  ┆ 11:27:52  ┆         ┆           │
# │ …          ┆ …          ┆           ┆          ┆   ┆ UTC       ┆ UTC       ┆         ┆           │
# │ 01944ad1-4 ┆ MQ_A5-Week ┆ 5514      ┆ M23+     ┆ … ┆ 2025-01-0 ┆ 2025-01-0 ┆ 401832  ┆ 53s       │
# │ e44-7921-b ┆ day-SDon-0 ┆           ┆          ┆   ┆ 9 11:33:4 ┆ 9         ┆         ┆           │
# │ fde-5772f8 ┆ 36100_SBS2 ┆           ┆          ┆   ┆ 1.806169  ┆ 11:28:45  ┆         ┆           │
# │ …          ┆ …          ┆           ┆          ┆   ┆ UTC       ┆ UTC       ┆         ┆           │
# └────────────┴────────────┴───────────┴──────────┴───┴───────────┴───────────┴─────────┴───────────┘

# %%
chart = df.plot.
